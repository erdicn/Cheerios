# %%
from scipy.special import kn 
import numpy as np
import matplotlib.pyplot as plot
x = np.arange(0.001, 10, 0.1)
y = []
for i in x:
    y.append(kn(1,x))
print(y)

plt.plot(x, y)
plt.show()
# Out:
# [array([99.97389412])]
